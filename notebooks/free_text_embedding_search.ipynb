# %%
import requests
import pandas as pd
import requests
import os
import json

API_URL = "https://www.ebi.ac.uk/ols4/api"
API_KEY = os.getenv('OPENAI_API_KEY')

if not API_KEY:
    raise ValueError("Please set the OPENAI_API_KEY environment variable.")

def embed_text(text):
    res = requests.post(
        'https://api.openai.com/v1/embeddings',
        headers={'Authorization': f'Bearer {API_KEY}'},
        json={'input': text, 'model': 'text-embedding-3-small'}
    )
    return res.json()['data'][0]['embedding']

def search_ols(vec):
    res = requests.post(f"{API_URL}/v2/classes/llm_embedding", data=json.dumps(vec), headers={
        'Content-Type': 'application/json'})
    return res.json()['elements']

vec = embed_text("diabetes mellitus")
res = search_ols(vec)

df = pd.DataFrame(res)
df = df[['ontologyId', 'curie', 'label', 'score']]

print(df.to_markdown(index=False))
# Out:
# | ontologyId   | curie          | label                                   |    score |
# |:-------------|:---------------|:----------------------------------------|---------:|
# | omit         | OMIT:0005196   | ['Diabetes Mellitus']                   | 0.924554 |
# | ordo         | ORDO:101952    | ['Rare diabetes mellitus']              | 0.9011   |
# | efo          | EFO:0006842    | ['diabetes mellitus biomarker']         | 0.854581 |
# | opmi         | OPMI:0004492   | ['Whether diabetes']                    | 0.848082 |
# | mondo        | MONDO:0005015  | ['diabetes mellitus']                   | 0.845779 |
# | efo          | EFO:0000400    | ['diabetes mellitus']                   | 0.839359 |
# | ncit         | NCIT:C2985     | ['Diabetes Mellitus']                   | 0.838554 |
# | doid         | DOID:9351      | ['diabetes mellitus']                   | 0.838237 |
# | omit         | OMIT:0005200   | ['Diabetes Mellitus, Type 2']           | 0.823695 |
# | mondo        | MONDO:1010574  | ['diabetes mellitus, dog']              | 0.82234  |
# | pw           | PW:0000176     | ['diabetes mellitus pathway']           | 0.821138 |
# | omit         | OMIT:0005198   | ['Diabetes Mellitus, Type 1']           | 0.819422 |
# | opmi         | OPMI:0004495   | ['What type of diabetes']               | 0.818399 |
# | doid         | DOID:9743      | ['diabetic neuropathy']                 | 0.812292 |
# | mondo        | MONDO:1010052  | ['diabetes mellitus, non-human animal'] | 0.810278 |
# | mondo        | MONDO:1010577  | ['diabetes mellitus, pig']              | 0.809763 |
# | omit         | OMIT:0032796   | ['IDDM3']                               | 0.80717  |
# | ogg          | OGG:3000003401 | ['IDDM2']                               | 0.807096 |
# | ogg          | OGG:3000003402 | ['IDDM3']                               | 0.806916 |
# | omit         | OMIT:0005197   | ['Diabetes Mellitus, Experimental']     | 0.805922 |
